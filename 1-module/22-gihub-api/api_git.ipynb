# %%
import requests
import time
import calendar
from datetime import datetime
import re

# %%
respuesta = requests.get("https://flask-zahid.herokuapp.com/recipes/1")

# %%
respuesta.json()
# Out:
# {'description': 'Unos taquitos así bien ricos', 'id': 1, 'name': 'Taquitos'}

# %%
respuesta = requests.post("https://flask-zahid.herokuapp.com/recipes", json = { "description": "La receta de Zahid",
                                                                               "name": "Ponc al carbon"})

# %%
respuesta.json()
# Out:
# {'description': 'La receta de Zahid', 'id': 3, 'name': 'Ponc al carbon'}

# %%
url = "https://api.github.com/"

def ruta(*args):
    return url + '/'.join(args)

# %%
ruta('users', 'herguejuan')
# Out:
# 'https://api.github.com/users/herguejuan'

# %%
respuesta = requests.get(ruta('users', 'herguejuan'))

# %%
respuesta
# Out:
# <Response [200]>

# %%
respuesta.json()
# Out:
# {'login': 'Herguejuan',
#  'id': 61879880,
#  'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Herguejuan',
#  'html_url': 'https://github.com/Herguejuan',
#  'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#  'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#  'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#  'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': None,
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 24,
#  'public_gists': 0,
#  'followers': 1,
#  'following': 0,
#  'created_at': '2020-03-06T15:32:34Z',
#  'updated_at': '2021-05-07T02:39:02Z'}

# %%
follow = requests.get('https://api.github.com/users/Herguejuan/followers')

# %%
#follow.json()

# %%
respuesta.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Sat, 15 May 2021 17:14:17 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"526c89127ad9f03ca9010f8f07b02f2be003cb393550239bd835d3d366f80125"', 'Last-Modified': 'Fri, 07 May 2021 02:39:02 GMT', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '58', 'X-RateLimit-Reset': '1621101510', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '2', 'Accept-Ranges': 'bytes', 'Content-Length': '457', 'X-GitHub-Request-Id': 'CB8F:1B28:57DFDC:13D081A:60A00169'}

# %%
respuesta.headers['X-RateLimit-Remaining']
# Out:
# '58'

# %%
respuesta.headers['Date']
# Out:
# 'Sat, 15 May 2021 17:14:17 GMT'

# %%
reset = respuesta.headers['X-RateLimit-Reset']
reset
# Out:
# '1621101510'

# %%
time.ctime(int(reset))
# Out:
# 'Sat May 15 12:58:30 2021'

# %%
def traducir_hora(hora):
    try:
        hora = float(hora)
    except:
        hora = re.findall(r"\d.*\d",hora)[0]
        hora = datetime.strptime(hora, "%d %b %Y %X").utctimetuple()
        hora = calendar.timegm(hora)
    return time.ctime(hora)

# %%
traducir_hora(reset)
# Out:
# 'Sat May 15 12:58:30 2021'

# %%
traducir_hora(respuesta.headers['Date'])
# Out:
# 'Sat May 15 12:14:17 2021'

# %%
respuesta.json()
# Out:
# {'login': 'Herguejuan',
#  'id': 61879880,
#  'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Herguejuan',
#  'html_url': 'https://github.com/Herguejuan',
#  'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#  'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#  'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#  'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': None,
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 24,
#  'public_gists': 0,
#  'followers': 1,
#  'following': 0,
#  'created_at': '2020-03-06T15:32:34Z',
#  'updated_at': '2021-05-07T02:39:02Z'}

# %%
ruta('users', 'Herguejuan', 'repos')
# Out:
# 'https://api.github.com/users/Herguejuan/repos'

# %%
repos = requests.get(ruta('users', 'Herguejuan', 'repos'))

# %%
repos
# Out:
# <Response [200]>

# %%
repos.json()
# Out:
# [{'id': 248875944,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNDg4NzU5NDQ=',
#   'name': 'data-prework',
#   'full_name': 'Herguejuan/data-prework',
#   'private': False,
#   'owner': {'login': 'Herguejuan',
#    'id': 61879880,
#    'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Herguejuan',
#    'html_url': 'https://github.com/Herguejuan',
#    'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#    'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#    'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#    'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Herguejuan/data-prework',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Herguejuan/data-prework',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/data-prework/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/data-prework/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/data-prework/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/data-prework/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/data-prework/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/data-prework/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/data-prework/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/data-prework/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/data-prework/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/data-prework/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/data-prework/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/data-prework/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/data-prework/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/data-prework/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/data-prework/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/data-prework/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/data-prework/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/data-prework/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/data-prework/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/data-prework/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/data-prework/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/data-prework/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Herguejuan/data-prework/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Herguejuan/data-prework/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Herguejuan/data-prework/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Herguejuan/data-prework/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Herguejuan/data-prework/merges',
#   'archive_url': 'https://api.github.com/repos/Herguejuan/data-prework/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Herguejuan/data-prework/downloads',
#   'issues_url': 'https://api.github.com/repos/Herguejuan/data-prework/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Herguejuan/data-prework/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Herguejuan/data-prework/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Herguejuan/data-prework/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Herguejuan/data-prework/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Herguejuan/data-prework/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Herguejuan/data-prework/deployments',
#   'created_at': '2020-03-21T00:05:54Z',
#   'updated_at': '2020-03-31T22:06:53Z',
#   'pushed_at': '2020-03-31T22:06:50Z',
#   'git_url': 'git://github.com/Herguejuan/data-prework.git',
#   'ssh_url': 'git@github.com:Herguejuan/data-prework.git',
#   'clone_url': 'https://github.com/Herguejuan/data-prework.git',
#   'svn_url': 'https://github.com/Herguejuan/data-prework',
#   'homepage': None,
#   'size': 219,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 249882123,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNDk4ODIxMjM=',
#   'name': 'datamex0320',
#   'full_name': 'Herguejuan/datamex0320',
#   'private': False,
#   'owner': {'login': 'Herguejuan',
#    'id': 61879880,
#    'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Herguejuan',
#    'html_url': 'https://github.com/Herguejuan',
#    'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#    'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#    'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#    'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Herguejuan/datamex0320',
#   'description': 'Data Analytics Bootcamp Mexico',
#   'fork': True,
#   'url': 'https://api.github.com/repos/Herguejuan/datamex0320',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/datamex0320/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/datamex0320/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/datamex0320/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/datamex0320/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/datamex0320/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/datamex0320/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/datamex0320/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/datamex0320/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/datamex0320/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/datamex0320/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/datamex0320/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/datamex0320/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/datamex0320/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/datamex0320/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/datamex0320/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/datamex0320/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/datamex0320/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/datamex0320/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/datamex0320/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/datamex0320/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/datamex0320/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/datamex0320/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Herguejuan/datamex0320/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Herguejuan/datamex0320/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Herguejuan/datamex0320/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Herguejuan/datamex0320/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Herguejuan/datamex0320/merges',
#   'archive_url': 'https://api.github.com/repos/Herguejuan/datamex0320/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Herguejuan/datamex0320/downloads',
#   'issues_url': 'https://api.github.com/repos/Herguejuan/datamex0320/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Herguejuan/datamex0320/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Herguejuan/datamex0320/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Herguejuan/datamex0320/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Herguejuan/datamex0320/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Herguejuan/datamex0320/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Herguejuan/datamex0320/deployments',
#   'created_at': '2020-03-25T03:53:53Z',
#   'updated_at': '2020-03-25T23:26:54Z',
#   'pushed_at': '2020-05-13T22:20:49Z',
#   'git_url': 'git://github.com/Herguejuan/datamex0320.git',
#   'ssh_url': 'git@github.com:Herguejuan/datamex0320.git',
#   'clone_url': 'https://github.com/Herguejuan/datamex0320.git',
#   'svn_url': 'https://github.com/Herguejuan/datamex0320',
#   'homepage': None,
#   'size': 255116,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'agpl-3.0',
#    'name': 'GNU Affero General Public License v3.0',
#    'spdx_id': 'AGPL-3.0',
#    'url': 'https://api.github.com/licenses/agpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTE='},
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 355727589,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNTU3Mjc1ODk=',
#   'name': 'DataRepo',
#   'full_name': 'Herguejuan/DataRepo',
#   'private': False,
#   'owner': {'login': 'Herguejuan',
#    'id': 61879880,
#    'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Herguejuan',
#    'html_url': 'https://github.com/Herguejuan',
#    'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#    'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#    'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#    'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Herguejuan/DataRepo',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Herguejuan/DataRepo',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/DataRepo/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/DataRepo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/DataRepo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/DataRepo/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/DataRepo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/DataRepo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/DataRepo/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/DataRepo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/DataRepo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/DataRepo/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/DataRepo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/DataRepo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/DataRepo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/DataRepo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/DataRepo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/DataRepo/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/DataRepo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/DataRepo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/DataRepo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/DataRepo/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/DataRepo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/DataRepo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Herguejuan/DataRepo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Herguejuan/DataRepo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Herguejuan/DataRepo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Herguejuan/DataRepo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Herguejuan/DataRepo/merges',
#   'archive_url': 'https://api.github.com/repos/Herguejuan/DataRepo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Herguejuan/DataRepo/downloads',
#   'issues_url': 'https://api.github.com/repos/Herguejuan/DataRepo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Herguejuan/DataRepo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Herguejuan/DataRepo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Herguejuan/DataRepo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Herguejuan/DataRepo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Herguejuan/DataRepo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Herguejuan/DataRepo/deployments',
#   'created_at': '2021-04-08T01:23:39Z',
#   'updated_at': '2021-04-10T03:22:20Z',
#   'pushed_at': '2021-04-10T03:22:18Z',
#   'git_url': 'git://github.com/Herguejuan/DataRepo.git',
#   'ssh_url': 'git@github.com:Herguejuan/DataRepo.git',
#   'clone_url': 'https://github.com/Herguejuan/DataRepo.git',
#   'svn_url': 'https://github.com/Herguejuan/DataRepo',
#   'homepage': None,
#   'size': 184,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 365330699,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjUzMzA2OTk=',
#   'name': 'lab-advanced-mysql',
#   'full_name': 'Herguejuan/lab-advanced-mysql',
#   'private': False,
#   'owner': {'login': 'Herguejuan',
#    'id': 61879880,
#    'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Herguejuan',
#    'html_url': 'https://github.com/Herguejuan',
#    'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#    'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#    'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#    'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Herguejuan/lab-advanced-mysql',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/merges',
#   'archive_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/downloads',
#   'issues_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-mysql/deployments',
#   'created_at': '2021-05-07T19:12:32Z',
#   'updated_at': '2021-05-07T19:58:23Z',
#   'pushed_at': '2021-05-07T19:58:20Z',
#   'git_url': 'git://github.com/Herguejuan/lab-advanced-mysql.git',
#   'ssh_url': 'git@github.com:Herguejuan/lab-advanced-mysql.git',
#   'clone_url': 'https://github.com/Herguejuan/lab-advanced-mysql.git',
#   'svn_url': 'https://github.com/Herguejuan/lab-advanced-mysql',
#   'homepage': None,
#   'size': 4,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 359623809,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNTk2MjM4MDk=',
#   'name': 'lab-advanced-regex',
#   'full_name': 'Herguejuan/lab-advanced-regex',
#   'private': False,
#   'owner': {'login': 'Herguejuan',
#    'id': 61879880,
#    'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Herguejuan',
#    'html_url': 'https://github.com/Herguejuan',
#    'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#    'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#    'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#    'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Herguejuan/lab-advanced-regex',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/merges',
#   'archive_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/downloads',
#   'issues_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Herguejuan/lab-advanced-regex/deployments',
#   'created_at': '2021-04-19T23:17:41Z',
#   'updated_at': '2021-04-25T19:35:22Z',
#   'pushed_at': '2021-04-25T19:35:19Z',
#   'git_url': 'git://github.com/Herguejuan/lab-advanced-regex.git',
#   'ssh_url': 'git@github.com:Herguejuan/lab-advanced-regex.git',
#   'clone_url': 'https://github.com/Herguejuan/lab-advanced-regex.git',
#   'svn_url': 'https://github.com/Herguejuan/lab-advanced-regex',
#   'homepage': None,
#   'size': 14,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 361661090,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE2NjEwOTA=',
#   'name': 'lab-data-vikings',
#   'full_name': 'Herguejuan/lab-data-vikings',
#   'private': False,
#   'owner': {'login': 'Herguejuan',
#    'id': 61879880,
#    'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Herguejuan',
#    'html_url': 'https://github.com/Herguejuan',
#    'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#    'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#    'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#    'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Herguejuan/lab-data-vikings',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/merges',
#   'archive_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/downloads',
#   'issues_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Herguejuan/lab-data-vikings/deployments',
#   'created_at': '2021-04-26T07:42:51Z',
#   'updated_at': '2021-04-26T08:54:28Z',
#   'pushed_at': '2021-04-26T08:54:25Z',
#   'git_url': 'git://github.com/Herguejuan/lab-data-vikings.git',
#   'ssh_url': 'git@github.com:Herguejuan/lab-data-vikings.git',
#   'clone_url': 'https://github.com/Herguejuan/lab-data-vikings.git',
#   'svn_url': 'https://github.com/Herguejuan/lab-data-vikings',
#   'homepage': None,
#   'size': 8,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 356676078,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNTY2NzYwNzg=',
#   'name': 'lab-dicts-sets-tuples',
#   'full_name': 'Herguejuan/lab-dicts-sets-tuples',
#   'private': False,
#   'owner': {'login': 'Herguejuan',
#    'id': 61879880,
#    'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Herguejuan',
#    'html_url': 'https://github.com/Herguejuan',
#    'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#    'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#    'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#    'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Herguejuan/lab-dicts-sets-tuples',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/merges',
#   'archive_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/downloads',
#   'issues_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Herguejuan/lab-dicts-sets-tuples/deployments',
#   'created_at': '2021-04-10T19:32:13Z',
#   'updated_at': '2021-04-12T17:52:22Z',
#   'pushed_at': '2021-04-12T17:52:19Z',
#   'git_url': 'git://github.com/Herguejuan/lab-dicts-sets-tuples.git',
#   'ssh_url': 'git@github.com:Herguejuan/lab-dicts-sets-tuples.git',
#   'clone_url': 'https://github.com/Herguejuan/lab-dicts-sets-tuples.git',
#   'svn_url': 'https://github.com/Herguejuan/lab-dicts-sets-tuples',
#   'homepage': None,
#   'size': 29,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 361652437,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE2NTI0Mzc=',
#   'name': 'lab-error-handling',
#   'full_name': 'Herguejuan/lab-error-handling',
#   'private': False,
#   'owner': {'login': 'Herguejuan',
#    'id': 61879880,
#    'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Herguejuan',
#    'html_url': 'https://github.com/Herguejuan',
#    'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#    'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#    'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#    'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Herguejuan/lab-error-handling',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Herguejuan/lab-error-handling',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/merges',
#   'archive_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/downloads',
#   'issues_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Herguejuan/lab-error-handling/deployments',
#   'created_at': '2021-04-26T07:11:16Z',
#   'updated_at': '2021-04-26T07:40:55Z',
#   'pushed_at': '2021-04-26T07:40:53Z',
#   'git_url': 'git://github.com/Herguejuan/lab-error-handling.git',
#   'ssh_url': 'git@github.com:Herguejuan/lab-error-handling.git',
#   'clone_url': 'https://github.com/Herguejuan/lab-error-handling.git',
#   'svn_url': 'https://github.com/Herguejuan/lab-error-handling',
#   'homepage': None,
#   'size': 12,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 361521269,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE1MjEyNjk=',
#   'name': 'lab-functional-programming',
#   'full_name': 'Herguejuan/lab-functional-programming',
#   'private': False,
#   'owner': {'login': 'Herguejuan',
#    'id': 61879880,
#    'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Herguejuan',
#    'html_url': 'https://github.com/Herguejuan',
#    'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#    'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#    'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#    'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Herguejuan/lab-functional-programming',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/lab-functional-programming/git/commits{/sha}',
# ...
#   'fork': True,
#   'url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/merges',
#   'archive_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/downloads',
#   'issues_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Herguejuan/project-build-your-own-game/deployments',
#   'created_at': '2021-04-21T02:12:53Z',
#   'updated_at': '2021-04-26T19:53:46Z',
#   'pushed_at': '2021-04-26T19:53:44Z',
#   'git_url': 'git://github.com/Herguejuan/project-build-your-own-game.git',
#   'ssh_url': 'git@github.com:Herguejuan/project-build-your-own-game.git',
#   'clone_url': 'https://github.com/Herguejuan/project-build-your-own-game.git',
#   'svn_url': 'https://github.com/Herguejuan/project-build-your-own-game',
#   'homepage': None,
#   'size': 4,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 361972609,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE5NzI2MDk=',
#   'name': 'Project1-Snake-Game',
#   'full_name': 'Herguejuan/Project1-Snake-Game',
#   'private': False,
#   'owner': {'login': 'Herguejuan',
#    'id': 61879880,
#    'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Herguejuan',
#    'html_url': 'https://github.com/Herguejuan',
#    'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#    'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#    'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#    'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Herguejuan/Project1-Snake-Game',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/merges',
#   'archive_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/downloads',
#   'issues_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Herguejuan/Project1-Snake-Game/deployments',
#   'created_at': '2021-04-27T03:48:20Z',
#   'updated_at': '2021-05-01T12:49:22Z',
#   'pushed_at': '2021-05-01T13:08:27Z',
#   'git_url': 'git://github.com/Herguejuan/Project1-Snake-Game.git',
#   'ssh_url': 'git@github.com:Herguejuan/Project1-Snake-Game.git',
#   'clone_url': 'https://github.com/Herguejuan/Project1-Snake-Game.git',
#   'svn_url': 'https://github.com/Herguejuan/Project1-Snake-Game',
#   'homepage': None,
#   'size': 12815,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 357289414,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNTcyODk0MTQ=',
#   'name': 'string-operations',
#   'full_name': 'Herguejuan/string-operations',
#   'private': False,
#   'owner': {'login': 'Herguejuan',
#    'id': 61879880,
#    'node_id': 'MDQ6VXNlcjYxODc5ODgw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61879880?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Herguejuan',
#    'html_url': 'https://github.com/Herguejuan',
#    'followers_url': 'https://api.github.com/users/Herguejuan/followers',
#    'following_url': 'https://api.github.com/users/Herguejuan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Herguejuan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Herguejuan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Herguejuan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Herguejuan/orgs',
#    'repos_url': 'https://api.github.com/users/Herguejuan/repos',
#    'events_url': 'https://api.github.com/users/Herguejuan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Herguejuan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Herguejuan/string-operations',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Herguejuan/string-operations',
#   'forks_url': 'https://api.github.com/repos/Herguejuan/string-operations/forks',
#   'keys_url': 'https://api.github.com/repos/Herguejuan/string-operations/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Herguejuan/string-operations/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Herguejuan/string-operations/teams',
#   'hooks_url': 'https://api.github.com/repos/Herguejuan/string-operations/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Herguejuan/string-operations/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Herguejuan/string-operations/events',
#   'assignees_url': 'https://api.github.com/repos/Herguejuan/string-operations/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Herguejuan/string-operations/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Herguejuan/string-operations/tags',
#   'blobs_url': 'https://api.github.com/repos/Herguejuan/string-operations/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Herguejuan/string-operations/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Herguejuan/string-operations/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Herguejuan/string-operations/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Herguejuan/string-operations/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Herguejuan/string-operations/languages',
#   'stargazers_url': 'https://api.github.com/repos/Herguejuan/string-operations/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Herguejuan/string-operations/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Herguejuan/string-operations/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Herguejuan/string-operations/subscription',
#   'commits_url': 'https://api.github.com/repos/Herguejuan/string-operations/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Herguejuan/string-operations/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Herguejuan/string-operations/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Herguejuan/string-operations/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Herguejuan/string-operations/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Herguejuan/string-operations/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Herguejuan/string-operations/merges',
#   'archive_url': 'https://api.github.com/repos/Herguejuan/string-operations/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Herguejuan/string-operations/downloads',
#   'issues_url': 'https://api.github.com/repos/Herguejuan/string-operations/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Herguejuan/string-operations/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Herguejuan/string-operations/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Herguejuan/string-operations/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Herguejuan/string-operations/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Herguejuan/string-operations/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Herguejuan/string-operations/deployments',
#   'created_at': '2021-04-12T17:55:57Z',
#   'updated_at': '2021-04-25T16:15:07Z',
#   'pushed_at': '2021-04-25T16:15:05Z',
#   'git_url': 'git://github.com/Herguejuan/string-operations.git',
#   'ssh_url': 'git@github.com:Herguejuan/string-operations.git',
#   'clone_url': 'https://github.com/Herguejuan/string-operations.git',
#   'svn_url': 'https://github.com/Herguejuan/string-operations',
#   'homepage': None,
#   'size': 411,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'}]

# %%
ruta('repos', 'herguejuan', 'lab-web-scrapping')
# Out:
# 'https://api.github.com/repos/herguejuan/lab-web-scrapping'

# %%
repo_web_sc = requests.get(ruta('repos', 'herguejuan', 'lab-web-scrapping'))

# %%
repo_web_sc
# Out:
# <Response [404]>

# %%
repo_web_sc.json()
# Out:
# {'message': 'Not Found',
#  'documentation_url': 'https://docs.github.com/rest/reference/repos#get-a-repository'}

# %%
repo_web_sc.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Sat, 15 May 2021 17:41:02 GMT', 'Content-Type': 'application/json; charset=utf-8', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Vary': 'Accept-Encoding, Accept, X-Requested-With', 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '52', 'X-RateLimit-Reset': '1621101510', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '8', 'Content-Length': '112', 'X-GitHub-Request-Id': 'CC43:294B:23C39C:3D21F4:60A007AE'}

# %%
ruta('repos', 'herguejuan', 'lab-web-scrapping','contents')
# Out:
# 'https://api.github.com/repos/herguejuan/lab-web-scrapping/contents'

# %%
cont_web = requests.get(ruta('repos', 'herguejuan', 'lab-web-scrapping','contents'))

# %%
cont_web
# Out:
# <Response [200]>

# %%
cont_web.json()
# Out:
# [{'name': 'README.md',
#   'path': 'README.md',
#   'sha': '9f4d7f683ea13cc813ae46085a2c1be271594157',
#   'size': 2121,
#   'url': 'https://api.github.com/repos/Herguejuan/lab-web-scrapping/contents/README.md?ref=master',
#   'html_url': 'https://github.com/Herguejuan/lab-web-scrapping/blob/master/README.md',
#   'git_url': 'https://api.github.com/repos/Herguejuan/lab-web-scrapping/git/blobs/9f4d7f683ea13cc813ae46085a2c1be271594157',
#   'download_url': 'https://raw.githubusercontent.com/Herguejuan/lab-web-scrapping/master/README.md',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/Herguejuan/lab-web-scrapping/contents/README.md?ref=master',
#    'git': 'https://api.github.com/repos/Herguejuan/lab-web-scrapping/git/blobs/9f4d7f683ea13cc813ae46085a2c1be271594157',
#    'html': 'https://github.com/Herguejuan/lab-web-scrapping/blob/master/README.md'}},
#  {'name': 'your-code',
#   'path': 'your-code',
#   'sha': '5ee7f85a6508d0cffd4ddea98832db429aecfa34',
#   'size': 0,
#   'url': 'https://api.github.com/repos/Herguejuan/lab-web-scrapping/contents/your-code?ref=master',
#   'html_url': 'https://github.com/Herguejuan/lab-web-scrapping/tree/master/your-code',
#   'git_url': 'https://api.github.com/repos/Herguejuan/lab-web-scrapping/git/trees/5ee7f85a6508d0cffd4ddea98832db429aecfa34',
#   'download_url': None,
#   'type': 'dir',
#   '_links': {'self': 'https://api.github.com/repos/Herguejuan/lab-web-scrapping/contents/your-code?ref=master',
#    'git': 'https://api.github.com/repos/Herguejuan/lab-web-scrapping/git/trees/5ee7f85a6508d0cffd4ddea98832db429aecfa34',
#    'html': 'https://github.com/Herguejuan/lab-web-scrapping/tree/master/your-code'}}]

# %%
ruta('repos', 'herguejuan', 'lab-web-scrapping','contents','your-code')
# Out:
# 'https://api.github.com/repos/herguejuan/lab-web-scrapping/contents/your-code'

# %%
your_code = requests.get(ruta('repos', 'herguejuan', 'lab-web-scrapping','contents', 'your-code'))

# %%
#requests.get('https://api.github.com/repos/herguejuan/lab-web-scrapping/contents/your-code')

# %%
your_code
# Out:
# <Response [200]>

# %%
for file in your_code.json():
    print(file['path'])
# Out:
# your-code/Learning.ipynb
# your-code/main.ipynb
