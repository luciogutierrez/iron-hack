# %% [markdown]
# # Matplotlib

# %%
# garantiza que las visualizacioines se representen en el propio block de notas.
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x1 = np.arange(0,10,1)
x2 = np.linspace(0,5,10)
plt.plot(x1, x1, label='linear')
plt.plot(x1, x2**2, label='quadratic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title('Linear vs Non Linear plots')
plt.legend()
plt.show()

# %%
fig, [ax1, ax2] = plt.subplots(1,2)

ax1.plot(x1,x2)
ax1.set_title('LINEAR PLOT')
ax1.set_xlabel('x label')
ax1.set_ylabel('y label')

x = np.arange(0,10,1)
y = np.linspace(0,5,10)
w = x**2
ax2.plot(x, y)
ax2.set_title('COSINE PLOT')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')

plt.show()

# %% [markdown]
# ## Correlación Positiva - Cuando una variable aumenta con el aumento de otra y viceversa.
# ## Correlación Negativa - Cuando una variable disminuye con el aumento de otra y viceversa.

# %%
x = np.random.randn(10)
y = np.random.randn(10)
plt.scatter(x,y)
plt.xlabel('x label')
plt.ylabel('y label')
# Out:
# Text(0, 0.5, 'y label')

# %% [markdown]
# # Gráficos Circulares

# %%
labels = ['Vegetariasn','Non-Vegetariasn','vegans']
sizes = [40,45,15]

# %%
explode = (0,0.1,0)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')
plt.show()
