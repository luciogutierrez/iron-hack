# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
# import data from dataset
data = pd.read_csv('liga-mx-clausura-2021.csv')
data.head()
df = data.copy()

# %%
# analize datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datos     171 non-null    object
#  1   Local     171 non-null    object
#  2   Marcador  171 non-null    object
#  3   Visita    171 non-null    object
#  4   Estadio   171 non-null    object
# dtypes: object(5)
# memory usage: 6.8+ KB

# %%
# fuction to extract the datetime match from string field
def get_jornada(x):
    jor1 = re.findall(r'\d+', x['Datos'])
    jor2 = jor1[0] 
    jor3 = jor1[4]
    lenday = len(jor1[0])
    lenid = len(jor1[4])
    lenjor = lenid - lenday
    jor4 = jor1[4][:lenjor]

    # Liguilla
    ident1 = 'Recalifica'
    ident2 = 'Cuartos'
    ident3 = 'Semifinal'
    ident4 = 'Final'
    if ident1 in x['Datos']:
        jor4 = 18
    if ident2 in x['Datos']:
        jor4 = 19
    if ident3 in x['Datos']:
        jor4 = 20
    if ident4 in x['Datos']:
        jor4 = 21

    return int(jor4)

# %%
# Adding datetime match field from string "Datos" field.
df['jornada'] = df.apply(get_jornada, axis=1)
df.head()
# Out:
#                                                Datos        Local Marcador  \
# 0  Viernes 8 de Enero de 2021Temporada 2020-2021T...  Puebla F.C.    1 - 1
# 1  Viernes 8 de Enero de 2021Temporada 2020-2021T...      Tijuana    0 - 0
# 2  Viernes 8 de Enero de 2021Temporada 2020-2021T...  Mazatlán FC    3 - 2
# 3  Sábado 9 de Enero de 2021Temporada 2020-2021To...        Atlas    0 - 2
# 4  Sábado 9 de Enero de 2021Temporada 2020-2021To...         UANL    2 - 0
#
#         Visita           Estadio  jornada
# 0  Guadalajara        Cuauhtémoc        1
# 1        PUMAS          Caliente        1
# 2       Necaxa  Estadio Mazatlán        1
# 3    Monterrey           Jalisco        1
# 4         León     Universitario        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datos     171 non-null    object
#  1   Local     171 non-null    object
#  2   Marcador  171 non-null    object
#  3   Visita    171 non-null    object
#  4   Estadio   171 non-null    object
#  5   jornada   171 non-null    int64
# dtypes: int64(1), object(5)
# memory usage: 8.1+ KB

# %%
# function to extract local result from "Marcador" field.
def get_marcador_local(x):
    marc = re.findall(r'\d+', x['Marcador'])
    return marc[0]

# %%
# function to extract visit result from "Marcador" field.
def get_marcador_visita(x):
    marc = re.findall(r'\d+', x['Marcador'])
    return marc[1]

# %%
# adding goals scdored and goals agains from field "Marcador"
df['gf'] = df.apply(get_marcador_local, axis=1).astype(int)
df['gc'] = df.apply(get_marcador_visita, axis=1).astype(int)
df['gt'] = df['gf'] + df['gc']
df.head()
# Out:
#                                                Datos        Local Marcador  \
# 0  Viernes 8 de Enero de 2021Temporada 2020-2021T...  Puebla F.C.    1 - 1
# 1  Viernes 8 de Enero de 2021Temporada 2020-2021T...      Tijuana    0 - 0
# 2  Viernes 8 de Enero de 2021Temporada 2020-2021T...  Mazatlán FC    3 - 2
# 3  Sábado 9 de Enero de 2021Temporada 2020-2021To...        Atlas    0 - 2
# 4  Sábado 9 de Enero de 2021Temporada 2020-2021To...         UANL    2 - 0
#
#         Visita           Estadio  jornada  gf  gc  gt
# 0  Guadalajara        Cuauhtémoc        1   1   1   2
# 1        PUMAS          Caliente        1   0   0   0
# 2       Necaxa  Estadio Mazatlán        1   3   2   5
# 3    Monterrey           Jalisco        1   0   2   2
# 4         León     Universitario        1   2   0   2

# %%
df.columns
# Out:
# Index(['Datos', 'Local', 'Marcador', 'Visita', 'Estadio', 'jornada', 'gf',
#        'gc', 'gt'],
#       dtype='object')

# %%
local = df.copy()
local = local[['Local', 'jornada', 'gf', 'gc','gt']].reset_index(drop=True)
local.rename(columns = {'Local':'equipo'}, inplace=True)
local['local'] = 'L'
local.head()
# Out:
#         equipo  jornada  gf  gc  gt local
# 0  Puebla F.C.        1   1   1   2     L
# 1      Tijuana        1   0   0   0     L
# 2  Mazatlán FC        1   3   2   5     L
# 3        Atlas        1   0   2   2     L
# 4         UANL        1   2   0   2     L

# %%
# reverse visit results to local's
visita = df.copy()
visita = visita[['Visita', 'jornada', 'gf', 'gc','gt']].reset_index(drop=True)
column_order = ['Visita','jornada', 'gc', 'gf','gt']
visita = visita[column_order]
visita.columns = ['Visita', 'jornada', 'gf', 'gc','gt']
visita.rename(columns = {'Visita':'equipo'}, inplace=True)
visita['local'] = 'V'
visita.head()
# Out:
#         equipo  jornada  gf  gc  gt local
# 0  Guadalajara        1   1   1   2     V
# 1        PUMAS        1   0   0   0     V
# 2       Necaxa        1   2   3   5     V
# 3    Monterrey        1   2   0   2     V
# 4         León        1   0   2   2     V

# %%
# merge local and visit results
tabla = pd.concat([local, visita])
tabla.head()
# Out:
#         equipo  jornada  gf  gc  gt local
# 0  Puebla F.C.        1   1   1   2     L
# 1      Tijuana        1   0   0   0     L
# 2  Mazatlán FC        1   3   2   5     L
# 3        Atlas        1   0   2   2     L
# 4         UANL        1   2   0   2     L

# %%
def normalize_team_name(x):
    name = x['equipo']
    if 'San Luis' in x['equipo']:
        name = 'San Luis'
    if 'Juárez' in x['equipo']:
        name = 'Juárez'
    if 'Querétaro' in x['equipo']:
        name = 'Querétaro'
    if 'Mazatlán' in x['equipo']:
        name = 'Mazatlán'
    if 'PUMAS' in x['equipo']:
        name = 'Pumas'
    if 'Puebla' in x['equipo']:
        name = 'Puebla'
    if 'Santos' in x['equipo']:
        name = 'Santos'
    if 'UANL' in x['equipo']:
        name = 'Tigres'
    return name

# %%
tabla['equipo'] = tabla.apply(normalize_team_name, axis=1)
tabla.head()
# Out:
#      equipo  jornada  gf  gc  gt local
# 0    Puebla        1   1   1   2     L
# 1   Tijuana        1   0   0   0     L
# 2  Mazatlán        1   3   2   5     L
# 3     Atlas        1   0   2   2     L
# 4    Tigres        1   2   0   2     L

# %%
# adding goals summary fields
tabla['gd'] = tabla['gf'] - tabla['gc']
tabla['pj'] = 1
tabla['pg'] = np.where( tabla['gf'] > tabla['gc'] ,1,0)
tabla['pe'] = np.where( tabla['gf'] == tabla['gc'] ,1,0)
tabla['pp'] = np.where( tabla['gf'] < tabla['gc'] ,1,0)
tabla.head(5)
# Out:
#      equipo  jornada  gf  gc  gt local  gd  pj  pg  pe  pp
# 0    Puebla        1   1   1   2     L   0   1   0   1   0
# 1   Tijuana        1   0   0   0     L   0   1   0   1   0
# 2  Mazatlán        1   3   2   5     L   1   1   1   0   0
# 3     Atlas        1   0   2   2     L  -2   1   0   0   1
# 4    Tigres        1   2   0   2     L   2   1   1   0   0

# %%
# function to compute points 
def suma_puntos(x):
    puntos = 0
    if x['pg'] == 1:
        puntos += 3
    if x['pe'] == 1:
        puntos += 1
    return puntos

# %%
# adding points field
tabla['pts'] = tabla.apply(suma_puntos, axis=1)
tabla.head(5)
# Out:
#      equipo  jornada  gf  gc  gt local  gd  pj  pg  pe  pp  pts
# 0    Puebla        1   1   1   2     L   0   1   0   1   0    1
# 1   Tijuana        1   0   0   0     L   0   1   0   1   0    1
# 2  Mazatlán        1   3   2   5     L   1   1   1   0   0    3
# 3     Atlas        1   0   2   2     L  -2   1   0   0   1    0
# 4    Tigres        1   2   0   2     L   2   1   1   0   0    3

# %%
tabla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 342 entries, 0 to 170
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   equipo   342 non-null    object
#  1   jornada  342 non-null    int64
#  2   gf       342 non-null    int32
#  3   gc       342 non-null    int32
#  4   gt       342 non-null    int32
#  5   local    342 non-null    object
#  6   gd       342 non-null    int32
#  7   pj       342 non-null    int64
#  8   pg       342 non-null    int32
#  9   pe       342 non-null    int32
#  10  pp       342 non-null    int32
#  11  pts      342 non-null    int64
# dtypes: int32(7), int64(3), object(2)
# memory usage: 25.4+ KB

# %%
tabla_acum = tabla.copy()
tabla_acum = tabla_acum[tabla_acum['jornada']<=17].sort_values(['equipo','jornada']).reset_index(drop=True)
tabla_acum["gf_a"] = tabla_acum.groupby(['equipo'])['gf'].cumsum(axis=0)
tabla_acum["gc_a"] = tabla_acum.groupby(['equipo'])['gc'].cumsum(axis=0)
tabla_acum["gt_a"] = tabla_acum.groupby(['equipo'])['gt'].cumsum(axis=0)
tabla_acum["gd_a"] = tabla_acum.groupby(['equipo'])['gd'].cumsum(axis=0)
tabla_acum["pj_a"] = tabla_acum.groupby(['equipo'])['pj'].cumsum(axis=0)
tabla_acum["pg_a"] = tabla_acum.groupby(['equipo'])['pg'].cumsum(axis=0)
tabla_acum["pe_a"] = tabla_acum.groupby(['equipo'])['pe'].cumsum(axis=0)
tabla_acum["pp_a"] = tabla_acum.groupby(['equipo'])['pp'].cumsum(axis=0)
tabla_acum["pts_a"] = tabla_acum.groupby(['equipo'])['pts'].cumsum(axis=0)

# %%
# tabla_acum[tabla_acum['equipo']=='Cruz Azul'].sort_values(by=['equipo','jornada'])
tabla_equipo = tabla_acum[(tabla_acum['equipo']=='Cruz Azul') | (tabla_acum['equipo']=='Atlas')].sort_values(by=['equipo','jornada'])

# %%
# create final statistical liga mx clausura 2021 file
tabla_acum.to_csv('liga-mx-c-2021.csv')

# %%
# Posición por jornada
sns.set(rc={'figure.figsize': (15, 8)})
ax = sns.lineplot(x='jornada', y='pts_a', hue='equipo', data=tabla_equipo)
ax.set_title('Posición por equipo jornada a jornada')
ax.set(xlabel='jornada', ylabel="puntos");

# %%
sns.set(rc={'figure.figsize': (15, 8)})
sns.scatterplot(x='jornada', y='gd_a', hue='equipo', data=tabla_equipo);
