# %%
# requisitos
# pip install pymngo, dnspython
# reiniciar el kernel

# %%
from pymongo import MongoClient
from bson.json_util import loads
import pprint

# %%
client = MongoClient("mongodb+srv://luckgutierrez:LuckLuck_1@Cluster0.5xg3o.mongodb.net/Cluster0?retryWrites=true&w=majority")

# %%
restaurants = client.ironhack.restaurants
restaurants
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-01.5xg3o.mongodb.net:27017', 'cluster0-shard-00-02.5xg3o.mongodb.net:27017', 'cluster0-shard-00-00.5xg3o.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-fcxaoe-shard-0', ssl=True), 'ironhack'), 'restaurants')

# %%
lista_restaurants = []
with open("restaurants.json") as f:
    for jsonDoc in f:
        data = loads(jsonDoc)
        lista_restaurants.append(data)
lista_restaurants[0]
# Out:
# {'address': {'building': '1007',
#   'coord': [-73.856077, 40.848447],
#   'street': 'Morris Park Ave',
#   'zipcode': '10462'},
#  'borough': 'Bronx',
#  'cuisine': 'Bakery',
#  'grades': [{'date': datetime.datetime(2014, 3, 3, 0, 0, tzinfo=<bson.tz_util.FixedOffset object at 0x0000014B5F118D90>),
#    'grade': 'A',
#    'score': 2},
#   {'date': datetime.datetime(2013, 9, 11, 0, 0, tzinfo=<bson.tz_util.FixedOffset object at 0x0000014B5F118D90>),
#    'grade': 'A',
#    'score': 6},
#   {'date': datetime.datetime(2013, 1, 24, 0, 0, tzinfo=<bson.tz_util.FixedOffset object at 0x0000014B5F118D90>),
#    'grade': 'A',
#    'score': 10},
#   {'date': datetime.datetime(2011, 11, 23, 0, 0, tzinfo=<bson.tz_util.FixedOffset object at 0x0000014B5F118D90>),
#    'grade': 'A',
#    'score': 9},
#   {'date': datetime.datetime(2011, 3, 10, 0, 0, tzinfo=<bson.tz_util.FixedOffset object at 0x0000014B5F118D90>),
#    'grade': 'B',
#    'score': 14}],
#  'name': 'Morris Park Bake Shop',
# ...

# %%
# post_1 = restaurants.insert_one(lista_restaurants[0])

# %%
# resultados = restaurants.insert_many(lista_restaurants)

# %%
pprint.pprint(restaurants.find_one({"grades.0.grade":"A"}))
# Out:
# {'_id': ObjectId('6096e3440f7a10802dedd61c'),
#  'address': {'building': '1007',
#              'coord': [-73.856077, 40.848447],
#              'street': 'Morris Park Ave',
#              'zipcode': '10462'},
#  'borough': 'Bronx',
#  'cuisine': 'Bakery',
#  'grades': [{'date': datetime.datetime(2014, 3, 3, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2013, 9, 11, 0, 0),
#              'grade': 'A',
#              'score': 6},
#             {'date': datetime.datetime(2013, 1, 24, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2011, 11, 23, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2011, 3, 10, 0, 0),
#              'grade': 'B',
#              'score': 14}],
#  'name': 'Morris Park Bake Shop',
#  'restaurant_id': '30075445'}

# %%
for restaurant in restaurants.find({"grades.0.grade":"A"}):
    pprint.pprint(restaurant)
# Out:
# {'_id': ObjectId('6096e3440f7a10802dedd61c'),
#  'address': {'building': '1007',
#              'coord': [-73.856077, 40.848447],
#              'street': 'Morris Park Ave',
#              'zipcode': '10462'},
#  'borough': 'Bronx',
#  'cuisine': 'Bakery',
#  'grades': [{'date': datetime.datetime(2014, 3, 3, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2013, 9, 11, 0, 0),
#              'grade': 'A',
#              'score': 6},
#             {'date': datetime.datetime(2013, 1, 24, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2011, 11, 23, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2011, 3, 10, 0, 0),
#              'grade': 'B',
#              'score': 14}],
#  'name': 'Morris Park Bake Shop',
#  'restaurant_id': '30075445'}
# {'_id': ObjectId('6096e44c0f7a10802dedd61d'),
# ...

# %%
restaurants.count_documents({"$and" : [{"grades.0.grade": "A"},{"grades.1.grade": "A"}]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35204320b917> in <module>
# ----> 1 restaurants.count_documents({"$and" : [{"grades.0.grade": "A"},{"grades.1.grade": "A"}]})
#
# NameError: name 'restaurants' is not defined
